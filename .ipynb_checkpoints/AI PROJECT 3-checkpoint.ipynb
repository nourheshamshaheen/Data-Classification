# %% [markdown]
# # ASSIGNMENT 3 - 7034, 7150
#
# ### Goals:
# 1. Exploring different classification models and performing tuning of their parameters.
# 2. Exploring different techniques for evaluating classification models.

# %%
# !pip install -q sklearn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1. Data Balancing
# The dataset is class-imbalanced. So, we balance the dataset, and randomly put aside the extra readings for the gamma “g” class to make both classes equal in size.
#
# ### 2. Data Split
# Then we split our dataset randomly so that the training set would form 70% of the dataset and the testing set would form 30% of it.
#
# ### 3. Data Preprocessing
# As a way to make our models more accurate, we preprocessed our data with 3 different scalers: StandardScaler, QuantileTransformer, and RobustScaler.

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, QuantileTransformer, RobustScaler

df = pd.read_csv('data.txt', sep=',', header=None)
features = ['fLength', 'fWidth', 'fSize', 'fConc', 'fConc1', 'fAsym', 'fM3Long', 'fM3Trans', 'fAlpha', 'fDist', 'class']
df.columns = features

# Data Balancing
g = df.groupby('class')
df = g.apply(lambda x: x.sample(g.size().min()).reset_index(drop=True))

# Data Splitting
dftrain, dftest = train_test_split(df, test_size=0.3)

# Popping Labels before preprocessing
y_train = dftrain.pop('class')
y_test = dftest.pop('class')

# Proving g_count and h_count are equal
g_count = 0
h_count = 0

for el in y_train:
    if el == 'g':
        g_count += 1
    else:
        h_count +=1

for el in y_test:
    if el == 'g':
        g_count += 1
    else:
        h_count +=1
        
print("G-count: " + str(g_count))
print("H-count: " + str(h_count))
# Out:
# G-count: 6688
# H-count: 6688

# %%
# Plotting counts of g & h
df['class'].value_counts().plot.pie(autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='class'>

# %%
# Plotting histograms of each feature

fig = plt.figure(figsize=(24, 15))
for i in range(len(features)-1):
    var = features[i]
    sub = fig.add_subplot(3, 5, i + 1)
    sub.set_xlabel(var)
    df[var].plot(kind = 'hist')

# %%
# Data Preprocessing
# StandardScaler
dftrain_new_values = StandardScaler().fit_transform(dftrain.values)
dftest_new_values = StandardScaler().fit_transform(dftest.values)

dftrain_new_std = pd.DataFrame(dftrain_new_values, index=dftrain.index, columns=dftrain.columns)
dftest_new_std = pd.DataFrame(dftest_new_values, index=dftest.index, columns=dftest.columns)

#QuantileTransformer
dftrain_new_values = QuantileTransformer().fit_transform(dftrain.values)
dftest_new_values = QuantileTransformer().fit_transform(dftest.values)

dftrain_new_qunt = pd.DataFrame(dftrain_new_values, index=dftrain.index, columns=dftrain.columns)
dftest_new_qunt = pd.DataFrame(dftest_new_values, index=dftest.index, columns=dftest.columns)

#RobustScaler
dftrain_new_values = RobustScaler().fit_transform(dftrain.values)
dftest_new_values = RobustScaler().fit_transform(dftest.values)

dftrain_new_robst = pd.DataFrame(dftrain_new_values, index=dftrain.index, columns=dftrain.columns)
dftest_new_robst = pd.DataFrame(dftest_new_values, index=dftest.index, columns=dftest.columns)

# %% [markdown]
# ### Scikit learn classifiers:
#
# - Decision Trees
# - Naive Bayes Classifier
# - Random Forests
# - AdaBoost
# - KNearest Neighbor (K-NN).
#
# ### Method:
# - Using cross-validation, we tune the parameters of each classifier.
# - We run each classifier 3 times, once on each set of preprocessed data using different preprocessing methods.
# - We test each classifier and compare accuracies.

# %%
from sklearn.tree import DecisionTreeClassifier 
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix, ConfusionMatrixDisplay

scores_prep1 = {'DecisionTree': 0, 'NaiveBayes': 0, 'RandomForest': 0, 'AdaBoost': 0, 'KNN': 0}
scores_prep2 = {'DecisionTree': 0, 'NaiveBayes': 0, 'RandomForest': 0, 'AdaBoost': 0, 'KNN': 0}
scores_prep3 = {'DecisionTree': 0, 'NaiveBayes': 0, 'RandomForest': 0, 'AdaBoost': 0, 'KNN': 0}

# %% [markdown]
# ## Decision Trees:

# %%
X_train1 = dftrain_new_std.copy()
Y_train1 = y_train.copy()

X_test1 = dftest_new_std.copy()
Y_test1 = y_test.copy()

X_train2 = dftrain_new_qunt.copy()
Y_train2 = y_train.copy()

X_test2 = dftest_new_qunt.copy()
Y_test2 = y_test.copy()

X_train3 = dftrain_new_robst.copy()
Y_train3 = y_train.copy()

X_test3 = dftest_new_robst.copy()
Y_test3 = y_test.copy()

clf1 = DecisionTreeClassifier()
clf1 = clf1.fit(X_train1, Y_train1)
score = clf1.score(X_test1, Y_test1)
scores_prep1['DecisionTree'] = score

clf2 = DecisionTreeClassifier()
clf2 = clf2.fit(X_train2, Y_train2)
score = clf2.score(X_test2, Y_test2)
scores_prep2['DecisionTree'] = score

clf3 = DecisionTreeClassifier()
clf3 = clf3.fit(X_train3, Y_train3)
score = clf3.score(X_test3, Y_test3)
scores_prep3['DecisionTree'] = score


Y_pred1 = clf1.predict(X_test1)
Y_pred2 = clf2.predict(X_test2)
Y_pred3 = clf3.predict(X_test3)


print('Classification Report 1:')
print(classification_report(Y_test1, Y_pred1))
print('Confusion Matrix 1:')
d1 = ConfusionMatrixDisplay(confusion_matrix(Y_test1, Y_pred1))
d1.plot()
plt.show()

print('Classification Report 2:')
print(classification_report(Y_test2, Y_pred2))
print('Confusion Matrix 2:')
d2 = ConfusionMatrixDisplay(confusion_matrix(Y_test2, Y_pred2))
d2.plot()
plt.show()

print('Classification Report 3:')
print(classification_report(Y_test3, Y_pred3))
print('Confusion Matrix 3:')
d3 = ConfusionMatrixDisplay(confusion_matrix(Y_test3, Y_pred3))
d3.plot()
plt.show()
# Out:
# Classification Report 1:
#               precision    recall  f1-score   support
#
#            g       0.82      0.78      0.80      2074
#            h       0.77      0.81      0.79      1939
#
#     accuracy                           0.80      4013
#    macro avg       0.80      0.80      0.80      4013
# weighted avg       0.80      0.80      0.80      4013
#
# Confusion Matrix 1:
# Classification Report 2:
#               precision    recall  f1-score   support
#
#            g       0.81      0.78      0.79      2074
#            h       0.77      0.81      0.79      1939
#
#     accuracy                           0.79      4013
#    macro avg       0.79      0.79      0.79      4013
# weighted avg       0.79      0.79      0.79      4013
#
# Confusion Matrix 2:
# Classification Report 3:
#               precision    recall  f1-score   support
#
#            g       0.82      0.77      0.80      2074
#            h       0.77      0.82      0.79      1939
#
#     accuracy                           0.79      4013
#    macro avg       0.80      0.80      0.79      4013
# weighted avg       0.80      0.79      0.79      4013
#
# Confusion Matrix 3:

# %% [markdown]
# ## Naive Bayes:

# %%
X_train1 = dftrain_new_std.copy()
Y_train1 = y_train.copy()

X_test1 = dftest_new_std.copy()
Y_test1 = y_test.copy()

X_train2 = dftrain_new_qunt.copy()
Y_train2 = y_train.copy()

X_test2 = dftest_new_qunt.copy()
Y_test2 = y_test.copy()

X_train3 = dftrain_new_robst.copy()
Y_train3 = y_train.copy()

X_test3 = dftest_new_robst.copy()
Y_test3 = y_test.copy()


clf1 = GaussianNB()
clf1 = clf1.fit(X_train1, Y_train1)
score = clf1.score(X_test1, Y_test1)
scores_prep1['NaiveBayes'] = score
Y_pred1 = clf1.predict(X_test1)

clf2 = GaussianNB()
clf2 = clf2.fit(X_train2, Y_train2)
score = clf2.score(X_test2, Y_test2)
scores_prep2['NaiveBayes'] = score
Y_pred2 = clf3.predict(X_test2)

clf3 = GaussianNB()
clf3 = clf3.fit(X_train3, Y_train3)
score = clf3.score(X_test3, Y_test3)
scores_prep3['NaiveBayes'] = score
Y_pred3 = clf3.predict(X_test3)

Y_pred1 = clf1.predict(X_test1)
Y_pred2 = clf2.predict(X_test2)
Y_pred3 = clf3.predict(X_test3)


print('Classification Report 1:')
print(classification_report(Y_test1, Y_pred1))
print('Confusion Matrix 1:')
d1 = ConfusionMatrixDisplay(confusion_matrix(Y_test1, Y_pred1))
d1.plot()
plt.show()

print('Classification Report 2:')
print(classification_report(Y_test2, Y_pred2))
print('Confusion Matrix 2:')
d2 = ConfusionMatrixDisplay(confusion_matrix(Y_test2, Y_pred2))
d2.plot()
plt.show()

print('Classification Report 3:')
print(classification_report(Y_test3, Y_pred3))
print('Confusion Matrix 3:')
d3 = ConfusionMatrixDisplay(confusion_matrix(Y_test3, Y_pred3))
d3.plot()
plt.show()
# Out:
# Classification Report 1:
#               precision    recall  f1-score   support
#
#            g       0.62      0.89      0.73      2074
#            h       0.77      0.41      0.54      1939
#
#     accuracy                           0.66      4013
#    macro avg       0.69      0.65      0.63      4013
# weighted avg       0.69      0.66      0.64      4013
#
# Confusion Matrix 1:
# Classification Report 2:
#               precision    recall  f1-score   support
#
#            g       0.74      0.80      0.77      2074
#            h       0.76      0.71      0.73      1939
#
#     accuracy                           0.75      4013
#    macro avg       0.75      0.75      0.75      4013
# weighted avg       0.75      0.75      0.75      4013
#
# Confusion Matrix 2:
# Classification Report 3:
#               precision    recall  f1-score   support
#
#            g       0.62      0.89      0.73      2074
#            h       0.78      0.41      0.53      1939
#
#     accuracy                           0.66      4013
#    macro avg       0.70      0.65      0.63      4013
# weighted avg       0.69      0.66      0.63      4013
#
# Confusion Matrix 3:

# %% [markdown]
# ## Ada Boost:

# %%
X_train1 = dftrain_new_std.copy()
Y_train1 = y_train.copy()

X_test1 = dftest_new_std.copy()
Y_test1 = y_test.copy()

X_train2 = dftrain_new_qunt.copy()
Y_train2 = y_train.copy()

X_test2 = dftest_new_qunt.copy()
Y_test2 = y_test.copy()

X_train3 = dftrain_new_robst.copy()
Y_train3 = y_train.copy()

X_test3 = dftest_new_robst.copy()
Y_test3 = y_test.copy()


clf1 = AdaBoostClassifier(n_estimators=100)
clf1 = clf1.fit(X_train1, Y_train1)
score = clf1.score(X_test1, Y_test1)
scores_prep1['AdaBoost'] = score

clf2 = AdaBoostClassifier(n_estimators=100)
clf2 = clf2.fit(X_train2, Y_train2)
score = clf2.score(X_test2, Y_test2)
scores_prep2['AdaBoost'] = score

clf3 = AdaBoostClassifier(n_estimators=100)
clf3 = clf3.fit(X_train3, Y_train3)
score = clf3.score(X_test3, Y_test3)
scores_prep3['AdaBoost'] = score

Y_pred1 = clf1.predict(X_test1)
Y_pred2 = clf2.predict(X_test2)
Y_pred3 = clf3.predict(X_test3)


print('Classification Report 1:')
print(classification_report(Y_test1, Y_pred1))
print('Confusion Matrix 1:')
d1 = ConfusionMatrixDisplay(confusion_matrix(Y_test1, Y_pred1))
d1.plot()
plt.show()

print('Classification Report 2:')
print(classification_report(Y_test2, Y_pred2))
print('Confusion Matrix 2:')
d2 = ConfusionMatrixDisplay(confusion_matrix(Y_test2, Y_pred2))
d2.plot()
plt.show()

print('Classification Report 3:')
print(classification_report(Y_test3, Y_pred3))
print('Confusion Matrix 3:')
d3 = ConfusionMatrixDisplay(confusion_matrix(Y_test3, Y_pred3))
d3.plot()
plt.show()
# Out:
# Classification Report 1:
#               precision    recall  f1-score   support
#
#            g       0.84      0.80      0.82      2074
#            h       0.80      0.83      0.81      1939
#
#     accuracy                           0.82      4013
#    macro avg       0.82      0.82      0.82      4013
# weighted avg       0.82      0.82      0.82      4013
#
# Confusion Matrix 1:
# Classification Report 2:
#               precision    recall  f1-score   support
#
#            g       0.84      0.80      0.82      2074
#            h       0.80      0.84      0.82      1939
#
#     accuracy                           0.82      4013
#    macro avg       0.82      0.82      0.82      4013
# weighted avg       0.82      0.82      0.82      4013
#
# Confusion Matrix 2:
# Classification Report 3:
#               precision    recall  f1-score   support
#
#            g       0.84      0.79      0.82      2074
#            h       0.79      0.84      0.82      1939
#
#     accuracy                           0.82      4013
#    macro avg       0.82      0.82      0.82      4013
# weighted avg       0.82      0.82      0.82      4013
#
# Confusion Matrix 3:

# %% [markdown]
# ## Random Forest:

# %%
X_train1 = dftrain_new_std.copy()
Y_train1 = y_train.copy()

X_test1 = dftest_new_std.copy()
Y_test1 = y_test.copy()

X_train2 = dftrain_new_qunt.copy()
Y_train2 = y_train.copy()

X_test2 = dftest_new_qunt.copy()
Y_test2 = y_test.copy()

X_train3 = dftrain_new_robst.copy()
Y_train3 = y_train.copy()

X_test3 = dftest_new_robst.copy()
Y_test3 = y_test.copy()


clf1 = RandomForestClassifier(n_estimators=100)
clf1 = clf1.fit(X_train1, Y_train1)
score = clf1.score(X_test1, Y_test1)
scores_prep1['RandomForest'] = score

clf2 = RandomForestClassifier(n_estimators=100)
clf2 = clf2.fit(X_train2, Y_train2)
score = clf2.score(X_test2, Y_test2)
scores_prep2['RandomForest'] = score

clf3 = RandomForestClassifier(n_estimators=100)
clf3 = clf3.fit(X_train3, Y_train3)
score = clf3.score(X_test3, Y_test3)
scores_prep3['RandomForest'] = score

Y_pred1 = clf1.predict(X_test1)
Y_pred2 = clf2.predict(X_test2)
Y_pred3 = clf3.predict(X_test3)


print('Classification Report 1:')
print(classification_report(Y_test1, Y_pred1))
print('Confusion Matrix 1:')
d1 = ConfusionMatrixDisplay(confusion_matrix(Y_test1, Y_pred1))
d1.plot()
plt.show()

print('Classification Report 2:')
print(classification_report(Y_test2, Y_pred2))
print('Confusion Matrix 2:')
d2 = ConfusionMatrixDisplay(confusion_matrix(Y_test2, Y_pred2))
d2.plot()
plt.show()

print('Classification Report 3:')
print(classification_report(Y_test3, Y_pred3))
print('Confusion Matrix 3:')
d3 = ConfusionMatrixDisplay(confusion_matrix(Y_test3, Y_pred3))
d3.plot()
plt.show()
# Out:
# Classification Report 1:
#               precision    recall  f1-score   support
#
#            g       0.85      0.87      0.86      2074
#            h       0.86      0.84      0.85      1939
#
#     accuracy                           0.86      4013
#    macro avg       0.86      0.86      0.86      4013
# weighted avg       0.86      0.86      0.86      4013
#
# Confusion Matrix 1:
# Classification Report 2:
#               precision    recall  f1-score   support
#
#            g       0.85      0.87      0.86      2074
#            h       0.85      0.83      0.84      1939
#
#     accuracy                           0.85      4013
#    macro avg       0.85      0.85      0.85      4013
# weighted avg       0.85      0.85      0.85      4013
#
# Confusion Matrix 2:
# Classification Report 3:
#               precision    recall  f1-score   support
#
#            g       0.86      0.86      0.86      2074
#            h       0.85      0.85      0.85      1939
#
#     accuracy                           0.86      4013
#    macro avg       0.86      0.86      0.86      4013
# weighted avg       0.86      0.86      0.86      4013
#
# Confusion Matrix 3:

# %% [markdown]
# ## K Nearest Neighbours:

# %%
X_train1 = dftrain_new_std.copy()
Y_train1 = y_train.copy()

X_test1 = dftest_new_std.copy()
Y_test1 = y_test.copy()

X_train2 = dftrain_new_qunt.copy()
Y_train2 = y_train.copy()

X_test2 = dftest_new_qunt.copy()
Y_test2 = y_test.copy()

X_train3 = dftrain_new_robst.copy()
Y_train3 = y_train.copy()

X_test3 = dftest_new_robst.copy()
Y_test3 = y_test.copy()


clf1 =  KNeighborsClassifier(20)
clf1 = clf1.fit(X_train1, Y_train1)
score = clf1.score(X_test1, Y_test1)
scores_prep1['KNN'] = score

clf2 =  KNeighborsClassifier(20)
clf2 = clf2.fit(X_train2, Y_train2)
score = clf2.score(X_test2, Y_test2)
scores_prep2['KNN'] = score

clf3 =  KNeighborsClassifier(20)
clf3 = clf3.fit(X_train3, Y_train3)
score = clf3.score(X_test3, Y_test3)
scores_prep3['KNN'] = score

Y_pred1 = clf1.predict(X_test1)
Y_pred2 = clf2.predict(X_test2)
Y_pred3 = clf3.predict(X_test3)


print('Classification Report 1:')
print(classification_report(Y_test1, Y_pred1))
print('Confusion Matrix 1:')
d1 = ConfusionMatrixDisplay(confusion_matrix(Y_test1, Y_pred1))
d1.plot()
plt.show()

print('Classification Report 2:')
print(classification_report(Y_test2, Y_pred2))
print('Confusion Matrix 2:')
d2 = ConfusionMatrixDisplay(confusion_matrix(Y_test2, Y_pred2))
d2.plot()
plt.show()

print('Classification Report 3:')
print(classification_report(Y_test3, Y_pred3))
print('Confusion Matrix 3:')
d3 = ConfusionMatrixDisplay(confusion_matrix(Y_test3, Y_pred3))
d3.plot()
plt.show()
# Out:
# Classification Report 1:
#               precision    recall  f1-score   support
#
#            g       0.78      0.90      0.84      2074
#            h       0.88      0.73      0.80      1939
#
#     accuracy                           0.82      4013
#    macro avg       0.83      0.82      0.82      4013
# weighted avg       0.83      0.82      0.82      4013
#
# Confusion Matrix 1:
# Classification Report 2:
#               precision    recall  f1-score   support
#
#            g       0.78      0.92      0.85      2074
#            h       0.90      0.73      0.80      1939
#
#     accuracy                           0.83      4013
#    macro avg       0.84      0.83      0.83      4013
# weighted avg       0.84      0.83      0.83      4013
#
# Confusion Matrix 2:
# Classification Report 3:
#               precision    recall  f1-score   support
#
#            g       0.77      0.91      0.84      2074
#            h       0.88      0.72      0.79      1939
#
#     accuracy                           0.81      4013
#    macro avg       0.83      0.81      0.81      4013
# weighted avg       0.82      0.81      0.81      4013
#
# Confusion Matrix 3:

# %% [markdown]
# ## Accuracy Scores:

# %%
print("Accuracy using StandardScaler: " + str(scores_prep1))
print("Accuracy using QuantileTransformer: " + str(scores_prep2))
print("Accuracy using RobustScaler: " + str(scores_prep3))
# Out:
# Accuracy using StandardScaler: {'DecisionTree': 0.7824570147022178, 'NaiveBayes': 0.6501370545726389, 'RandomForest': 0.8534762023423872, 'AdaBoost': 0.8153501121355594, 'KNN': 0.8101171193620733}
# Accuracy using QuantileTransformer: {'DecisionTree': 0.7787191627211563, 'NaiveBayes': 0.7488163468726639, 'RandomForest': 0.855968103663095, 'AdaBoost': 0.8218290555693994, 'KNN': 0.819087964116621}
# Accuracy using RobustScaler: {'DecisionTree': 0.7767256416645901, 'NaiveBayes': 0.6491402940443558, 'RandomForest': 0.8547221530027411, 'AdaBoost': 0.8138549713431348, 'KNN': 0.8078744081734364}

# %% [markdown]
# # BONUS: NEURAL NETWORK USING TENSOR FLOW

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import binary_crossentropy

# %%
loss_function = binary_crossentropy
additional_metrics = ['accuracy']
epochs = 400
verbosity_mode = 1
learning_rate = 0.005
momentum = 0.8
optimizer = Adam(learning_rate=learning_rate)

# %%
model = Sequential()
model.add(Dense(128, activation='tanh', input_dim = 10))
model.add(Dropout(0.4))
model.add(Dense(128, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               1408
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dense_2 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 18,049
# Trainable params: 18,049
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### The following figure shows the architecture of the neural network used:

# %%
# !pip install pydot
# !pip install graphviz
# Out:
# Requirement already satisfied: pydot in c:\users\nour hesham shaheen\anaconda3\lib\site-packages (1.4.2)
# Requirement already satisfied: pyparsing>=2.1.4 in c:\users\nour hesham shaheen\anaconda3\lib\site-packages (from pydot) (3.0.4)
# Requirement already satisfied: graphviz in c:\users\nour hesham shaheen\anaconda3\lib\site-packages (0.19.1)

# %%
from tensorflow import keras
from keras.utils.vis_utils import plot_model

plot_model(model, show_layer_names=True, show_layer_activations=True, to_file='model.png')
# Out:
# ('You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) ', 'for plot_model/model_to_dot to work.')

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

checkpoint = ModelCheckpoint('magic-gamma.h5', monitor='val_accuracy', save_best_only=True, verbose=verbosity_mode)
model.compile(loss=loss_function, metrics=additional_metrics, optimizer=optimizer)

# %%
X_train = dftrain_new_std.copy()
Y_train = y_train.copy()

X_test = dftest_new_std.copy()
Y_test = y_test.copy()

yn = (Y_train == 'g')
yt = (Y_test == 'g')
yn = yn.astype(int)
yt = yt.astype(int)

# Training
val_split = 0.2

history = model.fit(X_train, yn, epochs=epochs, validation_split=val_split, callbacks=[checkpoint])

clear_output()
# Out:
# Epoch 1/400
# 233/235 [============================>.] - ETA: 0s - loss: 0.2779 - accuracy: 0.8729
# Epoch 00001: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2779 - accuracy: 0.
400
# 182/235 [======================>.......] - ETA: 0s - loss: 0.2557 - accuracy: 0.8851
# Epoch 00079: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2611 - accuracy: 0.8824 - val_loss: 0.3783 - val_accuracy: 0.8484
# Epoch 80/400
# 184/235 [======================>.......] - ETA: 0s - loss: 0.2716 - accuracy: 0.8808
# Epoch 00080: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2714 - accuracy: 0.8809 - val_loss: 0.3823 - val_accuracy: 0.8505
# Epoch 81/400
# 183/235 [======================>.......] - ETA: 0s - loss: 0.2736 - accuracy: 0.8791
# Epoch 00081: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2746 - accuracy: 0.8781 - val_loss: 0.3760 - val_accuracy: 0.8500
# Epoch 82/400
# 184/235 [======================>.......] - ETA: 0s - loss: 0.2722 - accuracy: 0.8798
# Epoch 00082: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2724 - accuracy: 0.8786 - val_loss: 0.3666 - val_accuracy: 0.8489
# Epoch 83/400
# 178/235 [=====================>........] - ETA: 0s - loss: 0.2670 - accuracy: 0.8834
# Epoch 00083: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2670 - accuracy: 0.8816 - val_loss: 0.3761 - val_accuracy: 0.8500
# Epoch 84/400
# 185/235 [======================>.......] - ETA: 0s - loss: 0.2737 - accuracy: 0.8779
# Epoch 00084: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2720 - accuracy: 0.8778 - val_loss: 0.3792 - val_accuracy: 0.8494
# Epoch 85/400
# 181/235 [======================>.......] - ETA: 0s - loss: 0.2665 - accuracy: 0.8759
# Epoch 00085: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2682 - accuracy: 0.8758 - val_loss: 0.3855 - val_accuracy: 0.8494
# Epoch 86/400
# 182/235 [======================>.......] - ETA: 0s - loss: 0.2711 - accuracy: 0.8819
# Epoch 00086: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2763 - accuracy: 0.8789 - val_loss: 0.3831 - val_accuracy: 0.8478
# Epoch 87/400
# 182/235 [======================>.......] - ETA: 0s - loss: 0.2655 - accuracy: 0.8826
# Epoch 00087: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2643 - accuracy: 0.8853 - val_loss: 0.4000 - val_accuracy: 0.8478
# Epoch 88/400
# 182/235 [======================>.......] - ETA: 0s - loss: 0.2723 - accuracy: 0.8777
# Epoch 00088: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2763 - accuracy: 0.8761 - val_loss: 0.3790 - val_accuracy: 0.8473
# Epoch 89/400
# 185/235 [======================>.......] - ETA: 0s - loss: 0.2674 - accuracy: 0.8777
# Epoch 00089: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2700 - accuracy: 0.8770 - val_loss: 0.3817 - val_accuracy: 0.8510
# Epoch 90/400
# 184/235 [======================>.......] - ETA: 0s - loss: 0.2767 - accuracy: 0.8789
# Epoch 00090: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2774 - accuracy: 0.8788 - val_loss: 0.3823 - val_accuracy: 0.8473
# Epoch 91/400
# 180/235 [=====================>........] - ETA: 0s - loss: 0.2779 - accuracy: 0.8811
# Epoch 00091: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2772 - accuracy: 0.8788 - val_loss: 0.3851 - val_accuracy: 0.8510
# Epoch 92/400
# 184/235 [======================>.......] - ETA: 0s - loss: 0.2621 - accuracy: 0.8852
# Epoch 00092: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2642 - accuracy: 0.8837 - val_loss: 0.3804 - val_accuracy: 0.8441
# Epoch 93/400
# 183/235 [======================>.......] - ETA: 0s - loss: 0.2759 - accuracy: 0.8757
# Epoch 00093: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2759 - accuracy: 0.8778 - val_loss: 0.3989 - val_accuracy: 0.8468
# Epoch 94/400
# 186/235 [======================>.......] - ETA: 0s - loss: 0.2827 - accuracy: 0.8726
# Epoch 00094: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2808 - accuracy: 0.8742 - val_loss: 0.3720 - val_accuracy: 0.8500
# Epoch 95/400
# 184/235 [======================>.......] - ETA: 0s - loss: 0.2662 - accuracy: 0.8791
# Epoch 00095: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2680 - accuracy: 0.8790 - val_loss: 0.3790 - val_accuracy: 0.8532
# Epoch 96/400
# 185/235 [======================>.......] - ETA: 0s - loss: 0.2629 - accuracy: 0.8853
# Epoch 00096: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2657 - accuracy: 0.8837 - val_loss: 0.3887 - val_accuracy: 0.8478
# Epoch 97/400
# 184/235 [======================>.......] - ETA: 0s - loss: 0.2794 - accuracy: 0.8779
# Epoch 00097: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2762 - accuracy: 0.8782 - val_loss: 0.3897 - val_accuracy: 0.8484
# Epoch 98/400
# 187/235 [======================>.......] - ETA: 0s - loss: 0.2745 - accuracy: 0.8750
# Epoch 00098: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 993us/step - loss: 0.2708 - accuracy: 0.8777 - val_loss: 0.3841 - val_accuracy: 0.8494
# Epoch 99/400
# 226/235 [===========================>..] - ETA: 0s - loss: 0.2848 - accuracy: 0.8762
# Epoch 00099: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2850 - accuracy: 0.8766 - val_loss: 0.3839 - val_accuracy: 0.8430
# Epoch 100/400
# 233/235 [============================>.] - ETA: 0s - loss: 0.2748 - accuracy: 0.8781
# Epoch 00100: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2753 - accuracy: 0.8777 - val_loss: 0.3863 - val_accuracy: 0.8532
# Epoch 101/400
# 182/235 [======================>.......] - ETA: 0s - loss: 0.2631 - accuracy: 0.8822
# Epoch 00101: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2668 - accuracy: 0.8793 - val_loss: 0.3769 - val_accuracy: 0.8457
# Epoch 102/400
# 186/235 [======================>.......] - ETA: 0s - loss: 0.2726 - accuracy: 0.8782
# Epoch 00102: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2709 - accuracy: 0.8785 - val_loss: 0.3985 - val_accuracy: 0.8457
# Epoch 103/400
# 187/235 [======================>.......] - ETA: 0s - loss: 0.2647 - accuracy: 0.8862
# Epoch 00103: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2682 - accuracy: 0.8809 - val_loss: 0.3802 - val_accuracy: 0.8436
# Epoch 104/400
# 184/235 [======================>.......] - ETA: 0s - loss: 0.2625 - accuracy: 0.8811
# Epoch 00104: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2689 - accuracy: 0.8778 - val_loss: 0.3711 - val_accuracy: 0.8478
# Epoch 105/400
# 183/235 [======================>.......] - ETA: 0s - loss: 0.2801 - accuracy: 0.8718
# Epoch 00105: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2771 - accuracy: 0.8749 - val_loss: 0.3682 - val_accuracy: 0.8516
# Epoch 106/400
# 180/235 [=====================>........] - ETA: 0s - loss: 0.2636 - accuracy: 0.8823
# Epoch 00106: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2712 - accuracy: 0.8808 - val_loss: 0.3682 - val_accuracy: 0.8553
# Epoch 107/400
# 184/235 [======================>.......] - ETA: 0s - loss: 0.2697 - accuracy: 0.8769
# Epoch 00107: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2727 - accuracy: 0.8753 - val_loss: 0.3855 - val_accuracy: 0.8526
# Epoch 108/400
# 180/235 [=====================>........] - ETA: 0s - loss: 0.2692 - accuracy: 0.8793
# Epoch 00108: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2710 - accuracy: 0.8786 - val_loss: 0.3810 - val_accuracy: 0.8462
# Epoch 109/400
# 185/235 [======================>.......] - ETA: 0s - loss: 0.2610 - accuracy: 0.8829
# Epoch 00109: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2674 - accuracy: 0.8814 - val_loss: 0.3764 - val_accuracy: 0.8590
# Epoch 110/400
# 183/235 [======================>.......] - ETA: 0s - loss: 0.2694 - accuracy: 0.8818
# Epoch 00110: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2715 - accuracy: 0.8781 - val_loss: 0.3882 - val_accuracy: 0.8510
# Epoch 111/400
# 183/235 [======================>.......] - ETA: 0s - loss: 0.2748 - accuracy: 0.8798
# Epoch 00111: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2763 - accuracy: 0.8802 - val_loss: 0.3800 - val_accuracy: 0.8505
# Epoch 112/400
# 181/235 [======================>.......] - ETA: 0s - loss: 0.2731 - accuracy: 0.8778
# Epoch 00112: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2745 - accuracy: 0.8781 - val_loss: 0.3815 - val_accuracy: 0.8494
# Epoch 113/400
# 187/235 [======================>.......] - ETA: 0s - loss: 0.2731 - accuracy: 0.8758
# Epoch 00113: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2711 - accuracy: 0.8777 - val_loss: 0.3867 - val_accuracy: 0.8473
# Epoch 114/400
# 228/235 [============================>.] - ETA: 0s - loss: 0.2668 - accuracy: 0.8798
# Epoch 00114: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2684 - accuracy: 0.8789 - val_loss: 0.3811 - val_accuracy: 0.8457
# Epoch 115/400
# 183/235 [======================>.......] - ETA: 0s - loss: 0.2680 - accuracy: 0.8832
# Epoch 00115: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2701 - accuracy: 0.8833 - val_loss: 0.3652 - val_accuracy: 0.8494
# Epoch 116/400
# 183/235 [======================>.......] - ETA: 0s - loss: 0.2713 - accuracy: 0.8779
# Epoch 00116: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2717 - accuracy: 0.8773 - val_loss: 0.3823 - val_accuracy: 0.8425
# Epoch 117/400
# 210/235 [=========================>....] - ETA: 0s - loss: 0.2666 - accuracy: 0.8796
# Epoch 00117: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2716 - accuracy: 0.8764 - val_loss: 0.3838 - val_accuracy: 0.8516
# Epoch 118/400
# 183/235 [======================>.......] - ETA: 0s - loss: 0.2706 - accuracy: 0.8782
# Epoch 00118: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2708 - accuracy: 0.8781 - val_loss: 0.4018 - val_accuracy: 0.8462
# Epoch 119/400
# 179/235 [=====================>........] - ETA: 0s - loss: 0.2713 - accuracy: 0.8766
# Epoch 00119: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2727 - accuracy: 0.8766 - val_loss: 0.3824 - val_accuracy: 0.8446
# Epoch 120/400
# 183/235 [======================>.......] - ETA: 0s - loss: 0.2727 - accuracy: 0.8794
# Epoch 00120: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2700 - accuracy: 0.8796 - val_loss: 0.3932 - val_accuracy: 0.8516
# Epoch 121/400
# 176/235 [=====================>........] - ETA: 0s - loss: 0.2690 - accuracy: 0.8798
# Epoch 00121: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2739 - accuracy: 0.8772 - val_loss: 0.3752 - val_accuracy: 0.8532
# Epoch 122/400
# 183/235 [======================>.......] - ETA: 0s - loss: 0.2693 - accuracy: 0.8789
# Epoch 00122: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2694 - accuracy: 0.8794 - val_loss: 0.3735 - val_accuracy: 0.8532
# Epoch 123/400
# 229/235 [============================>.] - ETA: 0s - loss: 0.2713 - accuracy: 0.8805
# Epoch 00123: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2711 - accuracy: 0.8802 - val_loss: 0.3926 - val_accuracy: 0.8457
# Epoch 124/400
# 179/235 [=====================>........] - ETA: 0s - loss: 0.2678 - accuracy: 0.8804
# Epoch 00124: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2706 - accuracy: 0.8804 - val_loss: 0.3845 - val_accuracy: 0.8510
# Epoch 125/400
# 231/235 [============================>.] - ETA: 0s - loss: 0.2689 - accuracy: 0.8815
# Epoch 00125: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2685 - accuracy: 0.8816 - val_loss: 0.4021 - val_accuracy: 0.8516
# Epoch 126/400
# 183/235 [======================>.......] - ETA: 0s - loss: 0.2736 - accuracy: 0.8801
# Epoch 00126: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2736 - accuracy: 0.8784 - val_loss: 0.4038 - val_accuracy: 0.8489
# Epoch 127/400
# 181/235 [======================>.......] - ETA: 0s - loss: 0.2674 - accuracy: 0.8816
# Epoch 00127: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2748 - accuracy: 0.8792 - val_loss: 0.3733 - val_accuracy: 0.8500
# Epoch 128/400
# 183/235 [======================>.......] - ETA: 0s - loss: 0.2797 - accuracy: 0.8772
# Epoch 00128: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2795 - accuracy: 0.8780 - val_loss: 0.3765 - val_accuracy: 0.8489
# Epoch 129/400
# 185/235 [======================>.......] - ETA: 0s - loss: 0.2676 - accuracy: 0.8813
# Epoch 00129: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2708 - accuracy: 0.8797 - val_loss: 0.3903 - val_accuracy: 0.8532
# Epoch 130/400
# 180/235 [=====================>........] - ETA: 0s - loss: 0.2725 - accuracy: 0.8800
# Epoch 00130: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2745 - accuracy: 0.8802 - val_loss: 0.3762 - val_accuracy: 0.8462
# Epoch 131/400
# 179/235 [=====================>........] - ETA: 0s - loss: 0.2704 - accuracy: 0.8832
# Epoch 00131: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2705 - accuracy: 0.8830 - val_loss: 0.3746 - val_accuracy: 0.8505
# Epoch 132/400
# 185/235 [======================>.......] - ETA: 0s - loss: 0.2676 - accuracy: 0.8851
# Epoch 00132: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2696 - accuracy: 0.8834 - val_loss: 0.3950 - val_accuracy: 0.8553
# Epoch 133/400
# 185/235 [======================>.......] - ETA: 0s - loss: 0.2757 - accuracy: 0.8770
# Epoch 00133: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2748 - accuracy: 0.8788 - val_loss: 0.3605 - val_accuracy: 0.8564
# Epoch 134/400
# 184/235 [======================>.......] - ETA: 0s - loss: 0.2654 - accuracy: 0.8877
# Epoch 00134: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2698 - accuracy: 0.8856 - val_loss: 0.3608 - val_accuracy: 0.8484
# Epoch 135/400
# 182/235 [======================>.......] - ETA: 0s - loss: 0.2649 - accuracy: 0.8820
# Epoch 00135: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2660 - accuracy: 0.8817 - val_loss: 0.3960 - val_accuracy: 0.8462
# Epoch 136/400
# 180/235 [=====================>........] - ETA: 0s - loss: 0.2716 - accuracy: 0.8828
# Epoch 00136: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2693 - accuracy: 0.8833 - val_loss: 0.3872 - val_accuracy: 0.8510
# Epoch 137/400
# 229/235 [============================>.] - ETA: 0s - loss: 0.2638 - accuracy: 0.8852
# Epoch 00137: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2638 - accuracy: 0.8849 - val_loss: 0.3706 - val_accuracy: 0.8516
# Epoch 138/400
# 229/235 [============================>.] - ETA: 0s - loss: 0.2840 - accuracy: 0.8743
# Epoch 00138: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2837 - accuracy: 0.8742 - val_loss: 0.3813 - val_accuracy: 0.8500
# Epoch 139/400
# 182/235 [======================>.......] - ETA: 0s - loss: 0.2767 - accuracy: 0.8805
# Epoch 00139: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2749 - accuracy: 0.8794 - val_loss: 0.3822 - val_accuracy: 0.8473
# Epoch 140/400
# 183/235 [======================>.......] - ETA: 0s - loss: 0.2648 - accuracy: 0.8815
# Epoch 00140: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2686 - accuracy: 0.8790 - val_loss: 0.3859 - val_accuracy: 0.8484
# Epoch 141/400
# 231/235 [============================>.] - ETA: 0s - loss: 0.2634 - accuracy: 0.8834
# Epoch 00141: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2643 - accuracy: 0.8830 - val_loss: 0.3927 - val_accuracy: 0.8478
# Epoch 142/400
# 179/235 [=====================>........] - ETA: 0s - loss: 0.2625 - accuracy: 0.8836
# Epoch 00142: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2688 - accuracy: 0.8801 - val_loss: 0.3840 - val_accuracy: 0.8489
# Epoch 143/400
# 181/235 [======================>.......] - ETA: 0s - loss: 0.2648 - accuracy: 0.8833
# Epoch 00143: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2714 - accuracy: 0.8808 - val_loss: 0.3817 - val_accuracy: 0.8452
# Epoch 144/400
# 183/235 [======================>.......] - ETA: 0s - loss: 0.2709 - accuracy: 0.8793
# Epoch 00144: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2688 - accuracy: 0.8805 - val_loss: 0.3917 - val_accuracy: 0.8585
# Epoch 145/400
# 182/235 [======================>.......] - ETA: 0s - loss: 0.2743 - accuracy: 0.8834
# Epoch 00145: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2734 - accuracy: 0.8820 - val_loss: 0.3867 - val_accuracy: 0.8436
# Epoch 146/400
# 179/235 [=====================>........] - ETA: 0s - loss: 0.
400
# 181/235 [======================>.......] - ETA: 0s - loss: 0.2657 - accuracy: 0.8809
# Epoch 00167: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2692 - accuracy: 0.8798 - val_loss: 0.3824 - val_accuracy: 0.8500
# Epoch 168/400
# 177/235 [=====================>........] - ETA: 0s - loss: 0.2723 - accuracy: 0.8796
# Epoch 00168: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2693 - accuracy: 0.8808 - val_loss: 0.3910 - val_accuracy: 0.8532
# Epoch 169/400
# 182/235 [======================>.......] - ETA: 0s - loss: 0.2766 - accuracy: 0.8743
# Epoch 00169: val_accuracy did not improve from 0.86012
# ...
# Epoch 00192: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2711 - accuracy: 0.8832 - val_loss: 0.3882 - val_accuracy: 0.8542
# Epoch 193/400
# 181/235 [======================>.......] - ETA: 0s - loss: 0.2643 - accuracy: 0.8843
# Epoch 00193: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2682 - accuracy: 0.8812 - val_loss: 0.3888 - val_accuracy: 0.8462
# Epoch 194/400
# 182/235 [======================>.......] - ETA: 0s - loss: 0.2641 - accuracy: 0.8810
# Epoch 00194: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2655 - accuracy: 0.8813 - val_loss: 0.4078 - val_accuracy: 0.8494
# Epoch 195/400
# 187/235 [======================>.......] - ETA: 0s - loss: 0.2659 - accuracy: 0.8817
# Epoch 00195: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 997us/step - loss: 0.2701 - accuracy: 0.8794 - val_loss: 0.3736 - val_accuracy: 0.8473
# Epoch 196/400
# 235/235 [==============================] - ETA: 0s - loss: 0.2629 - accuracy: 0.8856
# Epoch 00196: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2629 - accuracy: 0.8856 - val_loss: 0.3642 - val_accuracy: 0.8505
# Epoch 197/400
# 181/235 [======================>.......] - ETA: 0s - loss: 0.2651 - accuracy: 0.8821
# Epoch 00197: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2632 - accuracy: 0.8850 - val_loss: 0.3750 - val_accuracy: 0.8489
# Epoch 198/400
# 184/235 [======================>.......] - ETA: 0s - loss: 0.2726 - accuracy: 0.8820
# Epoch 00198: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2701 - accuracy: 0.8837 - val_loss: 0.3904 - val_accuracy: 0.8468
# Epoch 199/400
# 182/235 [======================>.......] - ETA: 0s - loss: 0.2705 - accuracy: 0.8839
# Epoch 00199: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2726 - accuracy: 0.8829 - val_loss: 0.3800 - val_accuracy: 0.8558
# Epoch 200/400
# 182/235 [======================>.......] - ETA: 0s - loss: 0.2689 - accuracy: 0.8793
# Epoch 00200: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2655 - accuracy: 0.8822 - val_loss: 0.3795 - val_accuracy: 0.8441
# Epoch 201/400
# 184/235 [======================>.......] - ETA: 0s - loss: 0.2712 - accuracy: 0.8787
# Epoch 00201: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2708 - accuracy: 0.8820 - val_loss: 0.4013 - val_accuracy: 0.8452
# Epoch 202/400
# 177/235 [=====================>........] - ETA: 0s - loss: 0.2711 - accuracy: 0.8778
# Epoch 00202: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2674 - accuracy: 0.8797 - val_loss: 0.3771 - val_accuracy: 0.8468
# Epoch 203/400
# 233/235 [============================>.] - ETA: 0s - loss: 0.2715 - accuracy: 0.8808
# Epoch 00203: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2717 - accuracy: 0.8806 - val_loss: 0.3745 - val_accuracy: 0.8537
# Epoch 204/400
# 181/235 [======================>.......] - ETA: 0s - loss: 0.2556 - accuracy: 0.8867
# Epoch 00204: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2574 - accuracy: 0.8852 - val_loss: 0.3888 - val_accuracy: 0.8521
# Epoch 205/400
# 184/235 [======================>.......] - ETA: 0s - loss: 0.2578 - accuracy: 0.8871
# Epoch 00205: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2653 - accuracy: 0.8842 - val_loss: 0.3778 - val_accuracy: 0.8468
# Epoch 206/400
# 185/235 [======================>.......] - ETA: 0s - loss: 0.2672 - accuracy: 0.8853
# Epoch 00206: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2695 - accuracy: 0.8822 - val_loss: 0.3795 - val_accuracy: 0.8537
# Epoch 207/400
# 184/235 [======================>.......] - ETA: 0s - loss: 0.2653 - accuracy: 0.8855
# Epoch 00207: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2646 - accuracy: 0.8852 - val_loss: 0.4013 - val_accuracy: 0.8430
# Epoch 208/400
# 184/235 [======================>.......] - ETA: 0s - loss: 0.2651 - accuracy: 0.8869
# Epoch 00208: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2619 - accuracy: 0.8866 - val_loss: 0.3956 - val_accuracy: 0.8468
# Epoch 209/400
# 231/235 [============================>.] - ETA: 0s - loss: 0.2637 - accuracy: 0.8812
# Epoch 00209: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2645 - accuracy: 0.8806 - val_loss: 0.3894 - val_accuracy: 0.8505
# Epoch 210/400
# 180/235 [=====================>........] - ETA: 0s - loss: 0.2549 - accuracy: 0.8872
# Epoch 00210: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2633 - accuracy: 0.8865 - val_loss: 0.3746 - val_accuracy: 0.8505
# Epoch 211/400
# 181/235 [======================>.......] - ETA: 0s - loss: 0.2725 - accuracy: 0.8800
# Epoch 00211: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2713 - accuracy: 0.8813 - val_loss: 0.3582 - val_accuracy: 0.8574
# Epoch 212/400
# 184/235 [======================>.......] - ETA: 0s - loss: 0.2630 - accuracy: 0.8826
# Epoch 00212: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2625 - accuracy: 0.8828 - val_loss: 0.3821 - val_accuracy: 0.8505
# Epoch 213/400
# 183/235 [======================>.......] - ETA: 0s - loss: 0.2581 - accuracy: 0.8813
# Epoch 00213: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2605 - accuracy: 0.8817 - val_loss: 0.3897 - val_accuracy: 0.8516
# Epoch 214/400
# 182/235 [======================>.......] - ETA: 0s - loss: 0.2668 - accuracy: 0.8795
# Epoch 00214: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2686 - accuracy: 0.8785 - val_loss: 0.3776 - val_accuracy: 0.8484
# Epoch 215/400
# 184/235 [======================>.......] - ETA: 0s - loss: 0.2606 - accuracy: 0.8835
# Epoch 00215: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2634 - accuracy: 0.8828 - val_loss: 0.3861 - val_accuracy: 0.8489
# Epoch 216/400
# 185/235 [======================>.......] - ETA: 0s - loss: 0.2618 - accuracy: 0.8856
# Epoch 00216: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2665 - accuracy: 0.8826 - val_loss: 0.3824 - val_accuracy: 0.8446
# Epoch 217/400
# 183/235 [======================>.......] - ETA: 0s - loss: 0.2645 - accuracy: 0.8825
# Epoch 00217: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2676 - accuracy: 0.8806 - val_loss: 0.3800 - val_accuracy: 0.8452
# Epoch 218/400
# 184/235 [======================>.......] - ETA: 0s - loss: 0.2675 - accuracy: 0.8843
# Epoch 00218: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2668 - accuracy: 0.8844 - val_loss: 0.3721 - val_accuracy: 0.8548
# Epoch 219/400
# 179/235 [=====================>........] - ETA: 0s - loss: 0.2751 - accuracy: 0.8797
# Epoch 00219: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2744 - accuracy: 0.8808 - val_loss: 0.3858 - val_accuracy: 0.8505
# Epoch 220/400
# 183/235 [======================>.......] - ETA: 0s - loss: 0.2681 - accuracy: 0.8801
# Epoch 00220: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2615 - accuracy: 0.8833 - val_loss: 0.3943 - val_accuracy: 0.8484
# Epoch 221/400
# 182/235 [======================>.......] - ETA: 0s - loss: 0.2696 - accuracy: 0.8858
# Epoch 00221: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2641 - accuracy: 0.8868 - val_loss: 0.3869 - val_accuracy: 0.8500
# Epoch 222/400
# 181/235 [======================>.......] - ETA: 0s - loss: 0.2555 - accuracy: 0.8897
# Epoch 00222: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2595 - accuracy: 0.8874 - val_loss: 0.4026 - val_accuracy: 0.8542
# Epoch 223/400
# 233/235 [============================>.] - ETA: 0s - loss: 0.2622 - accuracy: 0.8808
# Epoch 00223: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2619 - accuracy: 0.8809 - val_loss: 0.3862 - val_accuracy: 0.8500
# Epoch 224/400
# 182/235 [======================>.......] - ETA: 0s - loss: 0.2635 - accuracy: 0.8841
# Epoch 00224: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2657 - accuracy: 0.8840 - val_loss: 0.3867 - val_accuracy: 0.8478
# Epoch 225/400
# 181/235 [======================>.......] - ETA: 0s - loss: 0.2531 - accuracy: 0.8895
# Epoch 00225: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2598 - accuracy: 0.8849 - val_loss: 0.3918 - val_accuracy: 0.8532
# Epoch 226/400
# 181/235 [======================>.......] - ETA: 0s - loss: 0.2584 - accuracy: 0.8843
# Epoch 00226: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2589 - accuracy: 0.8850 - val_loss: 0.4064 - val_accuracy: 0.8542
# Epoch 227/400
# 228/235 [============================>.] - ETA: 0s - loss: 0.2628 - accuracy: 0.8864
# Epoch 00227: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2625 - accuracy: 0.8868 - val_loss: 0.3824 - val_accuracy: 0.8462
# Epoch 228/400
# 184/235 [======================>.......] - ETA: 0s - loss: 0.2593 - accuracy: 0.8857
# Epoch 00228: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2654 - accuracy: 0.8826 - val_loss: 0.3925 - val_accuracy: 0.8478
# Epoch 229/400
# 181/235 [======================>.......] - ETA: 0s - loss: 0.2699 - accuracy: 0.8800
# Epoch 00229: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2647 - accuracy: 0.8828 - val_loss: 0.3928 - val_accuracy: 0.8510
# Epoch 230/400
# 187/235 [======================>.......] - ETA: 0s - loss: 0.2708 - accuracy: 0.8819
# Epoch 00230: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2712 - accuracy: 0.8817 - val_loss: 0.3892 - val_accuracy: 0.8553
# Epoch 231/400
# 180/235 [=====================>........] - ETA: 0s - loss: 0.2541 - accuracy: 0.8875
# Epoch 00231: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2583 - accuracy: 0.8861 - val_loss: 0.4043 - val_accuracy: 0.8494
# Epoch 232/400
# 182/235 [======================>.......] - ETA: 0s - loss: 0.2612 - accuracy: 0.8805
# Epoch 00232: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2621 - accuracy: 0.8798 - val_loss: 0.3869 - val_accuracy: 0.8510
# Epoch 233/400
# 180/235 [=====================>........] - ETA: 0s - loss: 0.2605 - accuracy: 0.8859
# Epoch 00233: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2619 - accuracy: 0.8862 - val_loss: 0.3768 - val_accuracy: 0.8526
# Epoch 234/400
# 182/235 [======================>.......] - ETA: 0s - loss: 0.2721 - accuracy: 0.8807
# Epoch 00234: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2687 - accuracy: 0.8842 - val_loss: 0.3870 - val_accuracy: 0.8548
# Epoch 235/400
# 182/235 [======================>.......] - ETA: 0s - loss: 0.2747 - accuracy: 0.8777
# Epoch 00235: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2724 - accuracy: 0.8797 - val_loss: 0.3780 - val_accuracy: 0.8558
# Epoch 236/400
# 181/235 [======================>.......] - ETA: 0s - loss: 0.2682 - accuracy: 0.8823
# Epoch 00236: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2617 - accuracy: 0.8861 - val_loss: 0.3816 - val_accuracy: 0.8500
# Epoch 237/400
# 179/235 [=====================>........] - ETA: 0s - loss: 0.2559 - accuracy: 0.8846
# Epoch 00237: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2601 - accuracy: 0.8822 - val_loss: 0.3993 - val_accuracy: 0.8436
# Epoch 238/400
# 177/235 [=====================>........] - ETA: 0s - loss: 0.2645 - accuracy: 0.8821
# Epoch 00238: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2682 - accuracy: 0.8810 - val_loss: 0.4061 - val_accuracy: 0.8521
# Epoch 239/400
# 178/235 [=====================>........] - ETA: 0s - loss: 0.2643 - accuracy: 0.8852
# Epoch 00239: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2649 - accuracy: 0.8848 - val_loss: 0.3779 - val_accuracy: 0.8516
# Epoch 240/400
# 180/235 [=====================>........] - ETA: 0s - loss: 0.2514 - accuracy: 0.8920
# Epoch 00240: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2615 - accuracy: 0.8862 - val_loss: 0.3857 - val_accuracy: 0.8505
# Epoch 241/400
# 229/235 [============================>.] - ETA: 0s - loss: 0.2696 - accuracy: 0.8806
# Epoch 00241: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 2ms/step - loss: 0.2686 - accuracy: 0.8816 - val_loss: 0.3733 - val_accuracy: 0.8494
# Epoch 242/400
# 217/235 [==========================>...] - ETA: 0s - loss: 0.2657 - accuracy: 0.8839
# Epoch 00242: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2648 - accuracy: 0.8837 - val_loss: 0.3920 - val_accuracy: 0.8526
# Epoch 243/400
# 189/235 [=======================>......] - ETA: 0s - loss: 0.2538 - accuracy: 0.8876
# Epoch 00243: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2558 - accuracy: 0.8849 - val_loss: 0.3985 - val_accuracy: 0.8494
# Epoch 244/400
# 223/235 [===========================>..] - ETA: 0s - loss: 0.2664 - accuracy: 0.8819
# Epoch 00244: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2653 - accuracy: 0.8830 - val_loss: 0.3953 - val_accuracy: 0.8510
# Epoch 245/400
# 204/235 [=========================>....] - ETA: 0s - loss: 0.2645 - accuracy: 0.8796
# Epoch 00245: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2633 - accuracy: 0.8808 - val_loss: 0.3979 - val_accuracy: 0.8457
# Epoch 246/400
# 226/235 [===========================>..] - ETA: 0s - loss: 0.2591 - accuracy: 0.8869
# Epoch 00246: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2608 - accuracy: 0.8858 - val_loss: 0.3858 - val_accuracy: 0.8473
# Epoch 247/400
# 228/235 [============================>.] - ETA: 0s - loss: 0.2574 - accuracy: 0.8872
# Epoch 00247: val_accuracy did not improve from 0.86012
# 235/235 [==============================] - 0s 1ms/step - loss: 0.2568 - accuracy: 0.8873 - val_loss: 0.3984 - val_accuracy: 0.8558
# Epoch 248/400
# 167/235 [====================>.........] - ETA: 0s - loss: 0.2671 - accuracy: 0.8782

# %%
Y_pred = model.predict(X_test)
Y_pred = np.where(Y_pred > 0.5, 1, 0)

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
print('Classification Report')
print(classification_report(yt, Y_pred))
print('Accuracy Score')
print(accuracy_score(yt, Y_pred))

d = ConfusionMatrixDisplay(confusion_matrix(yt, Y_pred))
d.plot()
plt.show()
